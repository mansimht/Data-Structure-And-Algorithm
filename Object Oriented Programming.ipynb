# %% [markdown]
# **Object Oriented Programing**
#
# 1. Data:
#    - Task Description
#    - Task is complete
#
# 2. Behaviour:
#    - Toggle task complete/Incomplete
#
# **Procedure Programming**
#
# - Data and behivour are spread out in same set stepe by step instructions when we need to use behaviour then manipulate data directly by changing overall state of application
#
# **Functional Programming**
#
# - Data and behaviour kept seperate when we want to use our behaviour and toggle to do tasks of mutating data directly behaviour abstracted a pure function which takes data as an input and returns updated copy of data as an output.

# %% [markdown]
# **Object Orientation**
#
# - Data and behaviour are special entity in our code which combine all data or attributes and behiviour or methods into easy to use container we want access the data or use the behaviours we do so through object.
#
# **4 Pillars of Object Orientation**
#
# 1. Encapsulation: combine all data and behaviour in single object. There class created and it contain object havings different tasks. Encapsulation bundle toogether related data and behaviour and limit data scope.
#
# 2. Abstraction: It is ability to hide complex logic from the user making the code write easier to use in other  places. A good example is sending email- open email client, type email and content and send. Like we just call class method directly without understand the logic behind the class
#
# 3. Inheritance: One class inherit all functionalities and attributes from another  class or multiple classes.
#
# 4. Polymorphism: It means having multiple forms. In OOP when use inheritance in our classes we can take advantage of polymorphism.

# %% [markdown]
# **The Python self**
#
# - Class methods must have an extra first parameter in the method definition. We do not give a value for this parameter when we call the method, Python provides it
#
# - If we have a method that takes no arguments, then we still have to have one argument.
#
# **The __init__ method**
#
# - It is similar to constructer in JAVA and C++.
#
# - It run as soon as object of class intiated
#
# - This method is helpful to do intialization you want to do in object.

# %%
class Dog:
  attr1 = "mammal"
  def __init__(self, name):
      self.name = name

rodger= Dog('Rodger')
print(rodger.name)
# Out:
# Rodger

# %%
#create class object with methods

class Dog:

    # class attribute
    attr1 = "mammal"

    # Instance attribute
    def __init__(self, name):
        self.name = name

    def speak(self):
        print("My name is {}".format(self.name))

# Driver code
# Object instantiation
Rodger = Dog("Rodger")
Tommy = Dog("Tommy")

# Accessing class methods
Rodger.speak()
Tommy.speak()
# Out:
# My name is Rodger
# My name is Tommy

# %%
#inheritance python

class Person(object):

    # __init__ is known as the constructor
    def __init__(self, name, idnumber):
        self.name = name
        self.idnumber = idnumber

    def display(self):
        print(self.name)
        print(self.idnumber)

    def details(self):
        print("My name is {}".format(self.name))
        print("IdNumber: {}".format(self.idnumber))

# child class
class Employee(Person):
    def __init__(self, name, idnumber, salary, post):
        self.salary = salary
        self.post = post

        # invoking the __init__ of the parent class
        Person.__init__(self, name, idnumber)

    def details(self):
        print("My name is {}".format(self.name))
        print("IdNumber: {}".format(self.idnumber))
        print("Post: {}".format(self.post))


# creation of an object variable or an instance
a = Employee('Rahul', 886012, 200000, "Intern")

# calling a function of the class Person using
# its instance
a.display()
a.details()
# Out:
# Rahul
# 886012
# My name is Rahul
# IdNumber: 886012
# Post: Intern
